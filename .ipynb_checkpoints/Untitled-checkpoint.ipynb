# %% [markdown]
# # Song Recommender

# %% [markdown]
# ## Connecting to API

# %%
import config
import pandas as pd
import time

# %%
config.client_id
# Out:
# '3e6ccb8c977741f9ac8f2d6f0132fa39'

# %%
import spotipy
import json
from spotipy.oauth2 import SpotifyClientCredentials


#Initialize SpotiPy with user credentias
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id= config.client_id,
                                                           client_secret= config.client_secret))

# %% [markdown]
# ## Defining a function that collects tracks of a playlist

# %%
def get_playlist_tracks(username, playlist_id):
    results = sp.user_playlist_tracks(username,playlist_id,market="GB")
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

# %% [markdown]
# ## Creating list of tracks and storing the audio features in a list

# %%
tracklist1 = get_playlist_tracks("spotify", "29RO0worSJjuu77SI7GXoR") #Rock
tracklist2 = get_playlist_tracks("spotify", "1z9nITIlc0tEaCwHaaeD66") #Pop
tracklist3 = get_playlist_tracks("spotify", "37i9dQZF1DXb57FjYWz00c") #80s hits
tracklist4 = get_playlist_tracks("spotify", "3NgkCmLvO7UrtMsVBEeFVU") #70s
tracklist4 = get_playlist_tracks("spotify", "0oCAqgEvTB59A4UUKBLIOd") #electronic hits
tracklist5 = get_playlist_tracks("spotify", "141guhSLUNzE58MqlIC4zT")# 80s, 90s
tracklist6 = get_playlist_tracks("spotify", "4xJKWeSbYKfff0dVrubQ8N") #All times
tracklist7 = get_playlist_tracks("spotify", "1h0CEZCm6IbFTbxThn6Xcs") # Classic music
tracklist8 = get_playlist_tracks("spotify", "6TeyryiZ2UEf3CbLXyztFA") # Classic Rock

# %%
tracklist = tracklist1 + tracklist2 + tracklist3 + tracklist4  + tracklist5 + tracklist6 + tracklist7 + tracklist8

# %%
len(tracklist)
# Out:
# 5462

# %%
list_of_audio_features=[]
for item in range(0, 1000):
    #print (tracks[item]["track"]["id"])
    list_of_audio_features.append(sp.audio_features(tracklist[item]["track"]["id"])[0])

# %%
df1=pd.DataFrame(list_of_audio_features)    
df1=df1[["danceability","energy","loudness","speechiness","acousticness",
    "instrumentalness","liveness","valence","tempo","id","duration_ms"]]

# %%
list_of_audio_features=[]
for item in range(1000,2000):
    #print (tracks[item]["track"]["id"])
    list_of_audio_features.append(sp.audio_features(tracklist[item]["track"]["id"])[0])

# %%
df2=pd.DataFrame(list_of_audio_features)    
df2=df2[["danceability","energy","loudness","speechiness","acousticness",
    "instrumentalness","liveness","valence","tempo","id","duration_ms"]]

# %%
list_of_audio_features=[]
for item in range(2001,3000):
    #print (tracks[item]["track"]["id"])
    list_of_audio_features.append(sp.audio_features(tracklist[item]["track"]["id"])[0])

# %%
df3=pd.DataFrame(list_of_audio_features)    
df3=df3[["danceability","energy","loudness","speechiness","acousticness",
    "instrumentalness","liveness","valence","tempo","id","duration_ms"]]

# %%
list_of_audio_features=[]
for item in range(3001,4000):
    #print (tracks[item]["track"]["id"])
    list_of_audio_features.append(sp.audio_features(tracklist[item]["track"]["id"])[0])

# %%
df4=pd.DataFrame(list_of_audio_features)    
df4=df4[["danceability","energy","loudness","speechiness","acousticness",
    "instrumentalness","liveness","valence","tempo","id","duration_ms"]]

# %%
list_of_audio_features=[]
for item in range(4001,5000):
    #print (tracks[item]["track"]["id"])
    list_of_audio_features.append(sp.audio_features(tracklist[item]["track"]["id"])[0])

# %%
df5=pd.DataFrame(list_of_audio_features)    
df5=df5[["danceability","energy","loudness","speechiness","acousticness",
    "instrumentalness","liveness","valence","tempo","id","duration_ms"]]

# %%
list_of_audio_features=[]
for item in range(5000,5462):
    #print (tracks[item]["track"]["id"])
    list_of_audio_features.append(sp.audio_features(tracklist[item]["track"]["id"])[0])

# %%
df6=pd.DataFrame(list_of_audio_features)    
df6=df6[["danceability","energy","loudness","speechiness","acousticness",
    "instrumentalness","liveness","valence","tempo","id","duration_ms"]]

# %%
df = pd.concat([df1,df2,df3,df4,df5,df6],axis = 0)

# %%
df
# Out:
#      danceability  energy  loudness  speechiness  acousticness  \
# 0           0.532   0.767    -5.509       0.0574      0.002870
# 1           0.447   0.954    -8.069       0.0751      0.023500
# 2           0.267   0.953    -4.899       0.0960      0.002110
# 3           0.572   0.835    -6.219       0.0317      0.171000
# 4           0.933   0.528    -6.472       0.1610      0.112000
# ..            ...     ...       ...          ...           ...
# 457         0.498   0.789    -5.724       0.0319      0.000856
# 458         0.588   0.826    -6.182       0.0569      0.035100
# 459         0.575   0.886    -5.182       0.0340      0.064700
# 460         0.611   0.833    -7.554       0.0351      0.021800
# 461         0.402   0.597    -9.258       0.0327      0.038500
#
#      instrumentalness  liveness  valence    tempo                      id  \
# 0            0.000513    0.3900    0.755  127.361  2SiXAy7TuUkycRVbbWDEpo
# 1            0.403000    0.2980    0.331  123.453  0bVtevEgtDIeRjCJbK3Lmv
# 2            0.000000    0.2830    0.568   84.989  0PdM2a6oIjqepoEfcJo0RO
# 3            0.000377    0.0702    0.795  129.981  7N3PAbqfTjSEU1edb2tY8j
# 4            0.312000    0.1630    0.754  109.967  5vdp5UmvTsnMEMESIF2Ym7
# ..                ...       ...      ...      ...                     ...
# 457          0.000006    0.1040    0.455  120.176  43z6scIZU2QcEieMQFAJRG
# 458          0.000000    0.4540    0.621  129.021  2ck13qfgRZ1msyEJlDqzvk
# 459          0.000187    0.7090    0.609   96.310  1Jaah2tmN9Hv81A87KZ1MU
# 460          0.000204    0.0923    0.793  108.498  786h4kDeZiX5nYvOwA3wtE
# 461          0.000002    0.1090    0.496   81.806  7c1Dar0pIAW7w5TzaGjt9t
#
#      duration_ms
# 0         210173
# 1         272027
# 2         267307
# 3         241600
# 4         214653
# ..           ...
# 457       164280
# 458       263653
# 459       244667
# 460       219893
# 461       287000
#
# [5459 rows x 11 columns]

# %%
df = df.drop_duplicates()

# %%
df
# Out:
#      danceability  energy  loudness  speechiness  acousticness  \
# 0           0.532   0.767    -5.509       0.0574       0.00287
# 1           0.447   0.954    -8.069       0.0751       0.02350
# 2           0.267   0.953    -4.899       0.0960       0.00211
# 3           0.572   0.835    -6.219       0.0317       0.17100
# 4           0.933   0.528    -6.472       0.1610       0.11200
# ..            ...     ...       ...          ...           ...
# 453         0.505   0.518    -8.601       0.0230       0.40300
# 454         0.543   0.790    -5.932       0.0358       0.00811
# 455         0.572   0.783    -6.398       0.0353       0.01720
# 458         0.588   0.826    -6.182       0.0569       0.03510
# 460         0.611   0.833    -7.554       0.0351       0.02180
#
#      instrumentalness  liveness  valence    tempo                      id  \
# 0            0.000513    0.3900    0.755  127.361  2SiXAy7TuUkycRVbbWDEpo
# 1            0.403000    0.2980    0.331  123.453  0bVtevEgtDIeRjCJbK3Lmv
# 2            0.000000    0.2830    0.568   84.989  0PdM2a6oIjqepoEfcJo0RO
# 3            0.000377    0.0702    0.795  129.981  7N3PAbqfTjSEU1edb2tY8j
# 4            0.312000    0.1630    0.754  109.967  5vdp5UmvTsnMEMESIF2Ym7
# ..                ...       ...      ...      ...                     ...
# 453          0.000000    0.1290    0.472   81.019  3ozomn4PrGEKEuusxX2HpC
# 454          0.000000    0.2380    0.339   80.923  6u1yKoh00WaoSpNp46RzKF
# 455          0.000000    0.1900    0.460  105.975  6jlqDfX8TQNxcaAz5oxYJA
# 458          0.000000    0.4540    0.621  129.021  2ck13qfgRZ1msyEJlDqzvk
# 460          0.000204    0.0923    0.793  108.498  786h4kDeZiX5nYvOwA3wtE
#
#      duration_ms
# 0         210173
# 1         272027
# 2         267307
# 3         241600
# 4         214653
# ..           ...
# 453       247307
# 454       236973
# 455       255493
# 458       263653
# 460       219893
#
# [4855 rows x 11 columns]

# %%
artist_list = []
song_list = []
id_list = []

for i in range(len(tracklist)):
    artist = tracklist[i]['track']['artists'][0]['name']
    song_name= tracklist[i]['track']['name']
    song_id =  tracklist[i]['track']['id']
    artist_list.append(artist)
    song_list.append(song_name)
    id_list.append(song_id)
# Out:
# '2SiXAy7TuUkycRVbbWDEpo'

# %%
song_info = {'artist':artist_list, 'song':song_list, 'id':id_list}

# %%
df_song_info = pd.DataFrame(song_info)

# %%
df_song_info = df_song_info.drop_duplicates()

# %%
df_song_info
# Out:
#                 artist                                          song  \
# 0                AC/DC                   You Shook Me All Night Long
# 1        Guns N' Roses                         Welcome To The Jungle
# 2          Def Leppard       Pour Some Sugar On Me - Remastered 2017
# 3            Van Halen                          Jump - 2015 Remaster
# 4                Queen  Another One Bites The Dust - Remastered 2011
# ...                ...                                           ...
# 5453   Sarah McLachlan                            Building a Mystery
# 5454  Seven Mary Three                                    Cumbersome
# 5455            O.A.R.               Shattered (Turn The Car Around)
# 5458        Paula Cole              Where Have All the Cowboys Gone?
# 5460    10,000 Maniacs                                These Are Days
#
#                           id
# 0     2SiXAy7TuUkycRVbbWDEpo
# 1     0bVtevEgtDIeRjCJbK3Lmv
# 2     0PdM2a6oIjqepoEfcJo0RO
# 3     7N3PAbqfTjSEU1edb2tY8j
# 4     5vdp5UmvTsnMEMESIF2Ym7
# ...                      ...
# 5453  3ozomn4PrGEKEuusxX2HpC
# 5454  6u1yKoh00WaoSpNp46RzKF
# 5455  6jlqDfX8TQNxcaAz5oxYJA
# 5458  2ck13qfgRZ1msyEJlDqzvk
# 5460  786h4kDeZiX5nYvOwA3wtE
#
# [4858 rows x 3 columns]

# %%
len(song_list)
# Out:
# 5462

# %%
tracklist[0]['track']['id']
# Out:
# '2SiXAy7TuUkycRVbbWDEpo'

# %%
df = pd.merge(df, df_song_info, on="id")

# %%
df
# Out:
#       danceability  energy  loudness  speechiness  acousticness  \
# 0            0.532   0.767    -5.509       0.0574       0.00287
# 1            0.447   0.954    -8.069       0.0751       0.02350
# 2            0.267   0.953    -4.899       0.0960       0.00211
# 3            0.572   0.835    -6.219       0.0317       0.17100
# 4            0.933   0.528    -6.472       0.1610       0.11200
# ...            ...     ...       ...          ...           ...
# 4850         0.505   0.518    -8.601       0.0230       0.40300
# 4851         0.543   0.790    -5.932       0.0358       0.00811
# 4852         0.572   0.783    -6.398       0.0353       0.01720
# 4853         0.588   0.826    -6.182       0.0569       0.03510
# 4854         0.611   0.833    -7.554       0.0351       0.02180
#
#       instrumentalness  liveness  valence    tempo                      id  \
# 0             0.000513    0.3900    0.755  127.361  2SiXAy7TuUkycRVbbWDEpo
# 1             0.403000    0.2980    0.331  123.453  0bVtevEgtDIeRjCJbK3Lmv
# 2             0.000000    0.2830    0.568   84.989  0PdM2a6oIjqepoEfcJo0RO
# 3             0.000377    0.0702    0.795  129.981  7N3PAbqfTjSEU1edb2tY8j
# 4             0.312000    0.1630    0.754  109.967  5vdp5UmvTsnMEMESIF2Ym7
# ...                ...       ...      ...      ...                     ...
# 4850          0.000000    0.1290    0.472   81.019  3ozomn4PrGEKEuusxX2HpC
# 4851          0.000000    0.2380    0.339   80.923  6u1yKoh00WaoSpNp46RzKF
# 4852          0.000000    0.1900    0.460  105.975  6jlqDfX8TQNxcaAz5oxYJA
# 4853          0.000000    0.4540    0.621  129.021  2ck13qfgRZ1msyEJlDqzvk
# 4854          0.000204    0.0923    0.793  108.498  786h4kDeZiX5nYvOwA3wtE
#
#       duration_ms            artist  \
# 0          210173             AC/DC
# 1          272027     Guns N' Roses
# 2          267307       Def Leppard
# 3          241600         Van Halen
# 4          214653             Queen
# ...           ...               ...
# 4850       247307   Sarah McLachlan
# 4851       236973  Seven Mary Three
# 4852       255493            O.A.R.
# 4853       263653        Paula Cole
# 4854       219893    10,000 Maniacs
#
#                                               song
# 0                      You Shook Me All Night Long
# 1                            Welcome To The Jungle
# 2          Pour Some Sugar On Me - Remastered 2017
# 3                             Jump - 2015 Remaster
# 4     Another One Bites The Dust - Remastered 2011
# ...                                            ...
# 4850                            Building a Mystery
# 4851                                    Cumbersome
# 4852               Shattered (Turn The Car Around)
# 4853              Where Have All the Cowboys Gone?
# 4854                                These Are Days
#
# [4855 rows x 13 columns]

# %%
df.sort_index(axis=1, inplace=True)

# %%
df
# Out:
#       acousticness            artist  danceability  duration_ms  energy  \
# 0          0.00287             AC/DC         0.532       210173   0.767
# 1          0.02350     Guns N' Roses         0.447       272027   0.954
# 2          0.00211       Def Leppard         0.267       267307   0.953
# 3          0.17100         Van Halen         0.572       241600   0.835
# 4          0.11200             Queen         0.933       214653   0.528
# ...            ...               ...           ...          ...     ...
# 4850       0.40300   Sarah McLachlan         0.505       247307   0.518
# 4851       0.00811  Seven Mary Three         0.543       236973   0.790
# 4852       0.01720            O.A.R.         0.572       255493   0.783
# 4853       0.03510        Paula Cole         0.588       263653   0.826
# 4854       0.02180    10,000 Maniacs         0.611       219893   0.833
#
#                           id  instrumentalness  liveness  loudness  \
# 0     2SiXAy7TuUkycRVbbWDEpo          0.000513    0.3900    -5.509
# 1     0bVtevEgtDIeRjCJbK3Lmv          0.403000    0.2980    -8.069
# 2     0PdM2a6oIjqepoEfcJo0RO          0.000000    0.2830    -4.899
# 3     7N3PAbqfTjSEU1edb2tY8j          0.000377    0.0702    -6.219
# 4     5vdp5UmvTsnMEMESIF2Ym7          0.312000    0.1630    -6.472
# ...                      ...               ...       ...       ...
# 4850  3ozomn4PrGEKEuusxX2HpC          0.000000    0.1290    -8.601
# 4851  6u1yKoh00WaoSpNp46RzKF          0.000000    0.2380    -5.932
# 4852  6jlqDfX8TQNxcaAz5oxYJA          0.000000    0.1900    -6.398
# 4853  2ck13qfgRZ1msyEJlDqzvk          0.000000    0.4540    -6.182
# 4854  786h4kDeZiX5nYvOwA3wtE          0.000204    0.0923    -7.554
#
#                                               song  speechiness    tempo  \
# 0                      You Shook Me All Night Long       0.0574  127.361
# 1                            Welcome To The Jungle       0.0751  123.453
# 2          Pour Some Sugar On Me - Remastered 2017       0.0960   84.989
# 3                             Jump - 2015 Remaster       0.0317  129.981
# 4     Another One Bites The Dust - Remastered 2011       0.1610  109.967
# ...                                            ...          ...      ...
# 4850                            Building a Mystery       0.0230   81.019
# 4851                                    Cumbersome       0.0358   80.923
# 4852               Shattered (Turn The Car Around)       0.0353  105.975
# 4853              Where Have All the Cowboys Gone?       0.0569  129.021
# 4854                                These Are Days       0.0351  108.498
#
#       valence
# 0       0.755
# 1       0.331
# 2       0.568
# 3       0.795
# 4       0.754
# ...       ...
# 4850    0.472
# 4851    0.339
# 4852    0.460
# 4853    0.621
# 4854    0.793
#
# [4855 rows x 13 columns]
